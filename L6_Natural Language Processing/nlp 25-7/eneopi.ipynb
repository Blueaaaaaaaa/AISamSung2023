# %%
# !wget -O eneopi.zip 'https://iloveptit.com/eneopi.zip'
# Out:
# --2023-07-25 11:59:39--  https://iloveptit.com/eneopi.zip
# Resolving iloveptit.com (iloveptit.com)... 95.111.198.69
# Connecting to iloveptit.com (iloveptit.com)|95.111.198.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5310955 (5.1M) [application/zip]
# Saving to: ‘eneopi.zip’
#
# eneopi.zip          100%[===================>]   5.06M  2.87MB/s    in 1.8s
#
# 2023-07-25 11:59:42 (2.87 MB/s) - ‘eneopi.zip’ saved [5310955/5310955]

# %%
import zipfile

zip_file_path = '/content/eneopi.zip'

extract_dir_path = '/content/'

# mở file zip và giải nén tất cả các file vào thư mục được chỉ định
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir_path)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# %cd /content//NLP
# Out:
# /content/NLP

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import math

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_list = []
cities = ['boston', 'chicago', 'la', 'montreal', 'ny', 'sf', 'toronto', 'vancouver']
for city in cities:
    df_tmp = pd.read_pickle('data_scientist_{}.pkl'.format(city))
    df_tmp['city'] = city
    df_list.append(df_tmp)

# %%
df_list[1]
# Out:
#                                              job_title  \
# 0                                       Data Scientist
# 1    100% REMOTE Data Scientist- Healthcare Claims/...
# 2                    Data Scientist - Machine Learning
# 3                                        Data Engineer
# 4                             Associate Data Scientist
# ..                                                 ...
# 359                  Data Scientist - Machine Learning
# 360                           Arity- Sr Data Scientist
# 361  Sr. Data Scientist: Computer Vision & Deep Lea...
# 362                              Senior Data Scientist
# 363                   Sr Actuarial Data Scientist-Auto
#
#                                            company  \
# 0                                       Workbridge
# 1                                      CyberCoders
# 2                                      CyberCoders
# 3        Spectrum Communications & Consulting Inc.
# 4    Blue Cross Blue Shield of IL, MT, NM, OK & TX
# ..                                             ...
# 359                                    CyberCoders
# 360                                       Allstate
# 361                                       Allstate
# 362                                       Allstate
# 363                                       Allstate
#
#                             location  \
# 0    - Chicago, IL 60603 (Loop area)
# 1    - Chicago, IL 60601 (Loop area)
# 2                      - Chicago, IL
# 3                      - Chicago, IL
# 4                      - Chicago, IL
# ..                               ...
# 359                    - Chicago, IL
# 360                    - Chicago, IL
# 361                    - Chicago, IL
# 362                    - Chicago, IL
# 363                    - Chicago, IL
#
#                                        job_description     city
# 0    Our client located in the heart of Chicago’s b...  chicago
# 1    100% REMOTE Data Scientist- Healthcare Claims/...  chicago
# 2    Data Scientist - Machine Learning\nIf you are ...  chicago
# 3    What do incubators and Spectrum have in common...  chicago
# 4    As part of our Government Programs Data Analyt...  chicago
# ..                                                 ...      ...
# 359  Data Scientist - Machine Learning\nIf you are ...  chicago
# 360  Founded by The Allstate Corporation in 2016, A...  chicago
# 361  Where good people build rewarding careers.\nTh...  chicago
# 362  Where good people build rewarding careers.\nTh...  chicago
# 363  Where good people build rewarding careers.\nTh...  chicago
#
# [364 rows x 5 columns]

# %%
df = pd.concat(df_list).reset_index(drop=True)

# %%
df
# Out:
#                                         job_title  \
# 0                           Junior Data Scientist
# 1                           Senior Data Scientist
# 2                                  Data Scientist
# 3                                  Data Scientist
# 4     Analyst II/Assistant Director, Data Science
# ...                                           ...
# 4134    Intermediate Accountant (Maternity Leave)
# 4135                   Human Resources Generalist
# 4136                      Data Developer - RACE21
# 4137                               Data Scientist
# 4138                 Environmental Lead Scientist
#
#                               company  \
# 0                        Pacific Life
# 1                             Invicro
# 2                            Trillium
# 3                       ENGIE Insight
# 4            Liberty Mutual Insurance
# ...                               ...
# 4134               Tantalus Labs Ltd.
# 4135            STEMCELL Technologies
# 4136           Teck Resources Limited
# 4137           Annex Consulting Group
# 4138  SynergyAspen Environmental Inc.
#
#                                             location  \
# 0                                       - Boston, MA
# 1             - Boston, MA 02210 (South Boston area)
# 2     - Boston, MA 02108 (Back Bay-Beacon Hill area)
# 3                                       - Boston, MA
# 4                                 - Boston, MA 02101
# ...                                              ...
# 4134                                 - Vancouver, BC
# 4135                                 - Vancouver, BC
# 4136                              - British Columbia
# 4137         - Metro Vancouver Regional District, BC
# 4138                                - Port Moody, BC
#
#                                         job_description       city
# 0     Purpose of Role:\nAs part of the PLRe Retro Pr...     boston
# 1     Overview:\nThe Senior Data Scientist will be a...     boston
# 2     Now hiring a Data Scientist in Boston, Massach...     boston
# 3     ENGIE Impact is accelerating sustainability tr...     boston
# 4     Liberty Mutual’s newly formed Global Risk Solu...     boston
# ...                                                 ...        ...
# 4134  The Company\nTantalus Labs is committed to Sun...  vancouver
# 4135  Job Description Summary\nThe Human Resources G...  vancouver
# 4136  Location: Vancouver, BC, CA\nWith a strong his...  vancouver
# 4137  Data Scientist\n\nContract- 9 months with exte...  vancouver
# 4138  We are currently recruiting for an Environment...  vancouver
#
# [4139 rows x 5 columns]

# %% [markdown]
# "job_title": Chức danh công việc.
#
# "company": Tên của công ty đang tuyển dụng.
#
# "location": Địa điểm của công việc (thành phố và khu vực cụ thể).
#
# "job_description": Mô tả chi tiết về vai trò và trách nhiệm của công việc.
#
# "city": Thành phố mà công ty đang tuyển dụng.
#
# Các vị trí tuyển dụng khá đa dạng, từ "Junior Data Scientist", "Senior Data Scientist", "Data Scientist", "Analyst II/Assistant Director, Data Science" đến "Intermediate Accountant", "Human Resources Generalist", "Data Developer" và "Environmental Lead Scientist".

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4139 entries, 0 to 4138
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        4139 non-null   object
#  1   company          4139 non-null   object
#  2   location         4139 non-null   object
#  3   job_description  4139 non-null   object
#  4   city             4139 non-null   object
# dtypes: object(5)
# memory usage: 161.8+ KB

# %%
df.shape
# Out:
# (4139, 5)

# %%
df['city'].value_counts()
# Out:
# ny           969
# sf           938
# boston       805
# chicago      364
# la           326
# toronto      267
# vancouver    248
# montreal     222
# Name: city, dtype: int64

# %%
msk = df['city'] == 'la'
df.loc[msk, 'city'] = 'los angeles'

msk = df['city'] == 'ny'
df.loc[msk, 'city'] = 'new york'

msk = df['city'] == 'sf'
df.loc[msk, 'city'] = 'san francisco'

# %%
df['city'].value_counts()
# Out:
# new york         969
# san francisco    938
# boston           805
# chicago          364
# los angeles      326
# toronto          267
# vancouver        248
# montreal         222
# Name: city, dtype: int64

# %%
print(df.shape)
df = df.drop_duplicates(subset=['job_description', 'city', 'job_title'])
print(df.shape)
# Out:
# (4139, 5)
# (2681, 5)

# %%
df.isna().sum()
# Out:
# job_title          0
# company            0
# location           0
# job_description    0
# city               0
# dtype: int64

# %%
df
# Out:
#                                         job_title  \
# 0                           Junior Data Scientist
# 1                           Senior Data Scientist
# 2                                  Data Scientist
# 3                                  Data Scientist
# 4     Analyst II/Assistant Director, Data Science
# ...                                           ...
# 4132                  Human Resources Coordinator
# 4133                 Technical Sourcing Recruiter
# 4134    Intermediate Accountant (Maternity Leave)
# 4135                   Human Resources Generalist
# 4137                               Data Scientist
#
#                              company  \
# 0                       Pacific Life
# 1                            Invicro
# 2                           Trillium
# 3                      ENGIE Insight
# 4           Liberty Mutual Insurance
# ...                              ...
# 4132           STEMCELL Technologies
# 4133  AMZN CAN Fulfillment Svcs, ULC
# 4134              Tantalus Labs Ltd.
# 4135           STEMCELL Technologies
# 4137          Annex Consulting Group
#
#                                             location  \
# 0                                       - Boston, MA
# 1             - Boston, MA 02210 (South Boston area)
# 2     - Boston, MA 02108 (Back Bay-Beacon Hill area)
# 3                                       - Boston, MA
# 4                                 - Boston, MA 02101
# ...                                              ...
# 4132                                 - Vancouver, BC
# 4133                                 - Vancouver, BC
# 4134                                 - Vancouver, BC
# 4135                                 - Vancouver, BC
# 4137         - Metro Vancouver Regional District, BC
#
#                                         job_description       city
# 0     Purpose of Role:\nAs part of the PLRe Retro Pr...     boston
# 1     Overview:\nThe Senior Data Scientist will be a...     boston
# 2     Now hiring a Data Scientist in Boston, Massach...     boston
# 3     ENGIE Impact is accelerating sustainability tr...     boston
# 4     Liberty Mutual’s newly formed Global Risk Solu...     boston
# ...                                                 ...        ...
# 4132  Job Description Summary\nThe Human Resources C...  vancouver
# 4133  Bachelor’s degree\nYou have 3+ years of corpor...  vancouver
# 4134  The Company\nTantalus Labs is committed to Sun...  vancouver
# 4135  Job Description Summary\nThe Human Resources G...  vancouver
# 4137  Data Scientist\n\nContract- 9 months with exte...  vancouver
#
# [2681 rows x 5 columns]

# %%
df['job_description'].iloc[12]
# Out:
# "What you will be doing\n\nAs a member of the data science team, you will be working alongside our technical experts and your role will be key to roll-out our different solutions to the clients.\n\nYour day-to-day:\nSet-up and deploy in production the data processing pipelines of our clients, including data reception in batches or in real-time, data cleaning, information extraction, calibration of fraud detection models, etc.\nR&D for product development and innovation (through machine learning, image analysis, NLP, trend analysis, chatbots…)\nWork closely with our clients to understand their needs, their feedback to improve our solutions\nWork closely with the sales team for prospects demo (and yes, that includes traveling worldwide!)\nTraining of junior Data scientists\n\nYour profile\n\nYou have a degree in mathematics and statistics (a specialization in machine learning and/or Big Data is a plus)\nYou are familiar with an object-oriented programming language and are willing to learn a new one (C#)\nYou combine strong analysis with synthesis abilities and are not afraid to deal with the details\nYou can write quality production code\nYou are comfortable dealing with clients\nYou are fluent in English (native speaker ideally) with degree or work experience in the US\n\nRecruitment process\n\n1. Screening Conversation with a recruiter (30-45 min)\n2. Tech Screening & face to face Interview (2 hours)\n3. Last interview with:\nHR (30 min)\nTeam Lead Interview (30 min)\n\nPerks and benefits\n\nBrand new office in the Financial District of Boston\nBusiness trip top Paris\nTeam building\nHealthcare program\nPension plan\nFrench standard annual leaves\n\nWant to know more?\n\nFull-time role, to start asap in Boston (MA, USA)\nAttractive compensation (depending on profile, experience, and expertise)\n\nTo apply, send us your resume and let us know why we could be a great fit!\nRecognized by Wired as one of Paris’ hottest startups and proud member of the Next40, here at Shift Technology we are using advanced artificial intelligence and data science to help revolutionize insurance from the inside out. We started with fraud, where we've built a fast-growing business that is scaling globally; and now we're helping insurance companies to automate claims, all the way from the user experience to the payment processing."

# %%
word_tokenize(str(df['job_description'].iloc[12]))
# Out:
# ['What',
#  'you',
#  'will',
#  'be',
#  'doing',
#  'As',
#  'a',
#  'member',
#  'of',
#  'the',
#  'data',
#  'science',
#  'team',
#  ',',
#  'you',
#  'will',
#  'be',
#  'working',
#  'alongside',
#  'our',
#  'technical',
#  'experts',
#  'and',
#  'your',
#  'role',
#  'will',
#  'be',
#  'key',
#  'to',
#  'roll-out',
#  'our',
#  'different',
#  'solutions',
#  'to',
#  'the',
#  'clients',
#  '.',
#  'Your',
#  'day-to-day',
#  ':',
#  'Set-up',
#  'and',
#  'deploy',
#  'in',
#  'production',
#  'the',
#  'data',
#  'processing',
#  'pipelines',
#  'of',
#  'our',
#  'clients',
#  ',',
#  'including',
#  'data',
#  'reception',
#  'in',
#  'batches',
#  'or',
#  'in',
#  'real-time',
#  ',',
#  'data',
#  'cleaning',
#  ',',
#  'information',
#  'extraction',
#  ',',
#  'calibration',
#  'of',
#  'fraud',
#  'detection',
#  'models',
#  ',',
#  'etc',
#  '.',
#  'R',
#  '&',
#  'D',
#  'for',
#  'product',
#  'development',
#  'and',
#  'innovation',
#  '(',
#  'through',
#  'machine',
#  'learning',
#  ',',
#  'image',
#  'analysis',
#  ',',
#  'NLP',
#  ',',
#  'trend',
#  'analysis',
#  ',',
#  'chatbots…',
#  ')',
#  'Work',
#  'closely',
#  'with',
#  'our',
#  'clients',
#  'to',
#  'understand',
#  'their',
#  'needs',
#  ',',
#  'their',
#  'feedback',
#  'to',
#  'improve',
#  'our',
#  'solutions',
#  'Work',
#  'closely',
#  'with',
#  'the',
#  'sales',
#  'team',
#  'for',
#  'prospects',
#  'demo',
#  '(',
#  'and',
#  'yes',
#  ',',
#  'that',
#  'includes',
#  'traveling',
#  'worldwide',
#  '!',
#  ')',
#  'Training',
#  'of',
#  'junior',
#  'Data',
#  'scientists',
#  'Your',
#  'profile',
#  'You',
#  'have',
#  'a',
#  'degree',
#  'in',
#  'mathematics',
#  'and',
#  'statistics',
#  '(',
#  'a',
#  'specialization',
#  'in',
#  'machine',
#  'learning',
#  'and/or',
#  'Big',
#  'Data',
#  'is',
#  'a',
#  'plus',
#  ')',
#  'You',
#  'are',
#  'familiar',
#  'with',
#  'an',
#  'object-oriented',
#  'programming',
#  'language',
#  'and',
#  'are',
#  'willing',
#  'to',
#  'learn',
#  'a',
#  'new',
#  'one',
#  '(',
#  'C',
#  '#',
#  ')',
#  'You',
#  'combine',
#  'strong',
#  'analysis',
#  'with',
#  'synthesis',
#  'abilities',
#  'and',
#  'are',
#  'not',
#  'afraid',
#  'to',
#  'deal',
#  'with',
#  'the',
#  'details',
#  'You',
#  'can',
#  'write',
#  'quality',
#  'production',
#  'code',
#  'You',
#  'are',
#  'comfortable',
#  'dealing',
#  'with',
#  'clients',
#  'You',
#  'are',
#  'fluent',
#  'in',
#  'English',
#  '(',
#  'native',
#  'speaker',
#  'ideally',
#  ')',
#  'with',
#  'degree',
#  'or',
#  'work',
#  'experience',
#  'in',
#  'the',
#  'US',
#  'Recruitment',
#  'process',
#  '1',
#  '.',
#  'Screening',
#  'Conversation',
#  'with',
#  'a',
#  'recruiter',
#  '(',
#  '30-45',
#  'min',
#  ')',
#  '2',
#  '.',
#  'Tech',
#  'Screening',
#  '&',
#  'face',
#  'to',
#  'face',
#  'Interview',
#  '(',
#  '2',
#  'hours',
#  ')',
#  '3',
#  '.',
#  'Last',
#  'interview',
#  'with',
#  ':',
#  'HR',
#  '(',
#  '30',
#  'min',
#  ')',
#  'Team',
#  'Lead',
#  'Interview',
#  '(',
#  '30',
#  'min',
#  ')',
#  'Perks',
#  'and',
#  'benefits',
#  'Brand',
#  'new',
#  'office',
#  'in',
#  'the',
#  'Financial',
#  'District',
#  'of',
#  'Boston',
#  'Business',
#  'trip',
#  'top',
#  'Paris',
#  'Team',
#  'building',
#  'Healthcare',
#  'program',
#  'Pension',
#  'plan',
#  'French',
#  'standard',
#  'annual',
#  'leaves',
#  'Want',
#  'to',
#  'know',
#  'more',
#  '?',
#  'Full-time',
#  'role',
#  ',',
#  'to',
#  'start',
#  'asap',
#  'in',
#  'Boston',
#  '(',
#  'MA',
#  ',',
#  'USA',
#  ')',
#  'Attractive',
#  'compensation',
#  '(',
#  'depending',
#  'on',
#  'profile',
#  ',',
#  'experience',
#  ',',
#  'and',
#  'expertise',
#  ')',
#  'To',
#  'apply',
#  ',',
#  'send',
#  'us',
#  'your',
#  'resume',
#  'and',
#  'let',
#  'us',
#  'know',
#  'why',
#  'we',
#  'could',
#  'be',
#  'a',
#  'great',
#  'fit',
#  '!',
#  'Recognized',
#  'by',
#  'Wired',
#  'as',
#  'one',
#  'of',
#  'Paris',
#  '’',
#  'hottest',
#  'startups',
#  'and',
#  'proud',
#  'member',
#  'of',
#  'the',
#  'Next40',
#  ',',
#  'here',
#  'at',
#  'Shift',
#  'Technology',
#  'we',
#  'are',
#  'using',
#  'advanced',
#  'artificial',
#  'intelligence',
#  'and',
#  'data',
#  'science',
#  'to',
#  'help',
#  'revolutionize',
#  'insurance',
#  'from',
#  'the',
#  'inside',
#  'out',
#  '.',
#  'We',
#  'started',
#  'with',
#  'fraud',
#  ',',
#  'where',
#  'we',
#  "'ve",
#  'built',
#  'a',
#  'fast-growing',
#  'business',
#  'that',
#  'is',
#  'scaling',
#  'globally',
#  ';',
#  'and',
#  'now',
#  'we',
#  "'re",
#  'helping',
#  'insurance',
#  'companies',
#  'to',
#  'automate',
#  'claims',
#  ',',
#  'all',
#  'the',
#  'way',
#  'from',
#  'the',
#  'user',
#  'experience',
#  'to',
#  'the',
#  'payment',
#  'processing',
#  '.']

# %% [markdown]
# #pos tag

# %%
from nltk import pos_tag
setp = ['as', 'a', 'member', 'of', 'the', 'data', 'science', 'team']
pos_tag(setp)
# Out:
# [('as', 'IN'),
#  ('a', 'DT'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  ('team', 'NN')]

# %%
'''
POS tag list:

CC	coordinating conjunction
CD	cardinal digit
DT	determiner
EX	existential there (like: "there is" ... think of it like "there exists")
FW	foreign word
IN	preposition/subordinating conjunction
JJ	adjective	'big'
JJR	adjective, comparative	'bigger'
JJS	adjective, superlative	'biggest'
LS	list marker	1)
MD	modal	could, will
NN	noun, singular 'desk'
NNS	noun plural	'desks'
NNP	proper noun, singular	'Harrison'
NNPS	proper noun, plural	'Americans'
PDT	predeterminer	'all the kids'
POS	possessive ending	parent\'s
PRP	personal pronoun	I, he, she
PRP$	possessive pronoun	my, his, hers
RB	adverb	very, silently,
RBR	adverb, comparative	better
RBS	adverb, superlative	best
RP	particle	give up
TO	to	go 'to' the store.
UH	interjection	errrrrrrrm
VB	verb, base form	take
VBD	verb, past tense	took
VBG	verb, gerund/present participle	taking
VBN	verb, past participle	taken
VBP	verb, sing. present, non-3d	take
VBZ	verb, 3rd person sing. present	takes
WDT	wh-determiner	which
WP	wh-pronoun	who, what
WP$	possessive wh-pronoun	whose
WRB	wh-abverb	where, when
'''
# Out:
# '\nPOS tag list:\n\nCC\tcoordinating conjunction\nCD\tcardinal digit\nDT\tdeterminer\nEX\texistential there (like: "there is" ... think of it like "there exists")\nFW\tforeign word\nIN\tpreposition/subordinating conjunction\nJJ\tadjective\t\'big\'\nJJR\tadjective, comparative\t\'bigger\'\nJJS\tadjective, superlative\t\'biggest\'\nLS\tlist marker\t1)\nMD\tmodal\tcould, will\nNN\tnoun, singular \'desk\'\nNNS\tnoun plural\t\'desks\'\nNNP\tproper noun, singular\t\'Harrison\'\nNNPS\tproper noun, plural\t\'Americans\'\nPDT\tpredeterminer\t\'all the kids\'\nPOS\tpossessive ending\tparent\'s\nPRP\tpersonal pronoun\tI, he, she\nPRP$\tpossessive pronoun\tmy, his, hers\nRB\tadverb\tvery, silently,\nRBR\tadverb, comparative\tbetter\nRBS\tadverb, superlative\tbest\nRP\tparticle\tgive up\nTO\tto\tgo \'to\' the store.\nUH\tinterjection\terrrrrrrrm\nVB\tverb, base form\ttake\nVBD\tverb, past tense\ttook\nVBG\tverb, gerund/present participle\ttaking\nVBN\tverb, past participle\ttaken\nVBP\tverb, sing. present, non-3d\ttake\nVBZ\tverb, 3rd person sing. present\ttakes\nWDT\twh-determiner\twhich\nWP\twh-pronoun\twho, what\nWP$\tpossessive wh-pronoun\twhose\nWRB\twh-abverb\twhere, when\n'

# %% [markdown]
# #Stemming
# - Stemming is the process of reducing a word to its stem that affixes to suffixes and prefixes.... Stemming is important in natural language understanding (NLU) and natural language processing (NLP).
#
# - connected, connection --> connect
# - pythoning, pythoned --> python
# - move, moved -> mov

# %%
from nltk.stem.snowball import PorterStemmer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()
#tool, skill, degree
# process the job description.
def prepare_job_desc(desc):
    # tokenize description.
    tokens = word_tokenize(desc) #

    # Parts of speech (POS) tag tokens.
    token_tag = pos_tag(tokens)
    include_tags = ['VBN', 'VBD', 'JJ', 'JJS', 'JJR', 'CD', 'NN', 'NNS', 'NNP', 'NNPS']
    filtered_tokens = []
    for tok, tag in token_tag:
        if tag in include_tags:
            filtered_tokens.append(tok)

    stemmed_tokens = []
    for tok in filtered_tokens:
        stemmed_token = ps.stem(tok).lower()
        stemmed_tokens.append(stemmed_token)

    return set(stemmed_tokens)
prepare_job_desc(df['job_description'].iloc[12])
# Out:
# {'1',
#  '2',
#  '3',
#  '30',
#  '30-45',
#  'abil',
#  'advanc',
#  'afraid',
#  'analysi',
#  'and/or',
#  'annual',
#  'artifici',
#  'asap',
#  'attract',
#  'batch',
#  'benefit',
#  'big',
#  'boston',
#  'brand',
#  'build',
#  'built',
#  'busi',
#  'c',
#  'calibr',
#  'chatbots…',
#  'claim',
#  'clean',
#  'client',
#  'code',
#  'comfort',
#  'compani',
#  'compens',
#  'convers',
#  'd',
#  'data',
#  'day-to-day',
#  'degre',
#  'demo',
#  'deploy',
#  'detail',
#  'detect',
#  'develop',
#  'differ',
#  'district',
#  'english',
#  'experi',
#  'expert',
#  'expertis',
#  'extract',
#  'face',
#  'familiar',
#  'fast-grow',
#  'feedback',
#  'financi',
#  'fit',
#  'fluent',
#  'fraud',
#  'french',
#  'full-tim',
#  'great',
#  'healthcar',
#  'hottest',
#  'hour',
#  'hr',
#  'imag',
#  'inform',
#  'innov',
#  'insid',
#  'insur',
#  'intellig',
#  'interview',
#  'junior',
#  'key',
#  'languag',
#  'last',
#  'lead',
#  'learn',
#  'leav',
#  'ma',
#  'machin',
#  'mathemat',
#  'member',
#  'min',
#  'model',
#  'more',
#  'nativ',
#  'need',
#  'new',
#  'next40',
#  'nlp',
#  'object-ori',
#  'offic',
#  'one',
#  'pari',
#  'payment',
#  'pension',
#  'perk',
#  'pipelin',
#  'plan',
#  'plu',
#  'process',
#  'product',
#  'profil',
#  'program',
#  'prospect',
#  'proud',
#  'qualiti',
#  'r',
#  'real-tim',
#  'recept',
#  'recogn',
#  'recruit',
#  'resum',
#  'role',
#  'sale',
#  'scienc',
#  'scientist',
#  'screen',
#  'set-up',
#  'shift',
#  'solut',
#  'speaker',
#  'special',
#  'standard',
#  'start',
#  'startup',
#  'statist',
#  'strong',
#  'synthesi',
#  'team',
#  'tech',
#  'technic',
#  'technolog',
#  'top',
#  'train',
#  'trend',
#  'trip',
#  'us',
#  'usa',
#  'user',
#  'way',
#  'will',
#  'wire',
#  'work',
#  '’'}

# %%
df['job_description_word_set'] = df['job_description'].apply(prepare_job_desc)
# Out:
# <ipython-input-88-a1224ed60e4e>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tool_keywords1 = ['python', 'pytorch', 'sql', 'mxnet', 'mlflow', 'einstein', 'theano', 'pyspark', 'solr', 'mahout',
 'cassandra', 'aws', 'powerpoint', 'spark', 'pig', 'sas', 'java', 'nosql', 'docker', 'salesforce', 'scala', 'r',
 'c', 'c++', 'net', 'tableau', 'pandas', 'scikitlearn', 'sklearn', 'matlab', 'scala', 'keras', 'tensorflow', 'clojure',
 'caffe', 'scipy', 'numpy', 'matplotlib', 'vba', 'spss', 'linux', 'azure', 'cloud', 'gcp', 'mongodb', 'mysql', 'oracle',
 'redshift', 'snowflake', 'kafka', 'javascript', 'qlik', 'jupyter', 'perl', 'bigquery', 'unix', 'react',
 'scikit', 'powerbi', 's3', 'ec2', 'lambda', 'ssrs', 'kubernetes', 'hana', 'spacy', 'tf', 'django', 'sagemaker',
 'seaborn', 'mllib', 'github', 'git', 'elasticsearch', 'splunk', 'airflow', 'looker', 'rapidminer', 'birt', 'pentaho',
 'jquery', 'nodejs', 'd3', 'plotly', 'bokeh', 'xgboost', 'rstudio', 'shiny', 'dash', 'h20', 'h2o', 'hadoop', 'mapreduce',
 'hive', 'cognos', 'angular', 'nltk', 'flask', 'node', 'firebase', 'bigtable', 'rust', 'php', 'cntk', 'lightgbm',
 'kubeflow', 'rpython', 'unixlinux', 'postgressql', 'postgresql', 'postgres', 'hbase', 'dask', 'ruby', 'julia', 'tensor',
# added r packages doesn't seem to impact the result
 'dplyr','ggplot2','esquisse','bioconductor','shiny','lubridate','knitr','mlr','quanteda','dt','rcrawler','caret','rmarkdown',
 'leaflet','janitor','ggvis','plotly','rcharts','rbokeh','broom','stringr','magrittr','slidify','rvest',
 'rmysql','rsqlite','prophet','glmnet','text2vec','snowballc','quantmod','rstan','swirl','datasciencer']


tool_keywords2 = set(['amazon web services', 'google cloud', 'sql server'])

skill_keywords1 = set(['statistics', 'cleansing', 'chatbot', 'cleaning', 'blockchain', 'causality', 'correlation', 'bandit', 'anomaly', 'kpi',
 'dashboard', 'geospatial', 'ocr', 'econometrics', 'pca', 'gis', 'svm', 'svd', 'tuning', 'hyperparameter', 'hypothesis',
 'salesforcecom', 'segmentation', 'biostatistics', 'unsupervised', 'supervised', 'exploratory',
 'recommender', 'recommendations', 'research', 'sequencing', 'probability', 'reinforcement', 'graph', 'bioinformatics',
 'chi', 'knn', 'outlier', 'etl', 'normalization', 'classification', 'optimizing', 'prediction', 'forecasting',
 'clustering', 'cluster', 'optimization', 'visualization', 'nlp', 'c#',
 'regression', 'logistic', 'nn', 'cnn', 'glm',
 'rnn', 'lstm', 'gbm', 'boosting', 'recurrent', 'convolutional', 'bayesian',
 'bayes'])


skill_keywords2 = set(['random forest', 'natural language processing', 'machine learning', 'decision tree', 'deep learning', 'experimental design',
 'time series', 'nearest neighbors', 'neural network', 'support vector machine', 'computer vision', 'machine vision', 'dimensionality reduction',
 'text analytics', 'power bi', 'a/b testing', 'ab testing', 'chat bot', 'data mining'])


degree_dict = {'bs': 1, 'bachelor': 1, 'undergraduate': 1,
               'master': 2, 'graduate': 2, 'mba': 2.5,
               'phd': 3, 'ph.d': 3, 'ba': 1, 'ma': 2,
               'postdoctoral': 4, 'postdoc': 4, 'doctorate': 3}


degree_dict2 = {'advanced degree': 2, 'ms or': 2, 'ms degree': 2, '4 year degree': 1, 'bs/': 1, 'ba/': 1,
                '4-year degree': 1, 'b.s.': 1, 'm.s.': 2, 'm.s': 2, 'b.s': 1, 'phd/': 3, 'ph.d.': 3, 'ms/': 2,
                'm.s/': 2, 'm.s./': 2, 'msc/': 2, 'master/': 2, 'master\'s/': 2, 'bachelor\s/': 1}
degree_keywords2 = set(degree_dict2.keys())

# %%
# process the keywords
tool_keywords1_set = set([ps.stem(tok) for tok in tool_keywords1]) # stem the keywords (since the job description is also stemmed.)
tool_keywords1_dict = {ps.stem(tok):tok for tok in tool_keywords1} # use this dictionary to revert the stemmed words back to the original.


skill_keywords1_set = set([ps.stem(tok) for tok in skill_keywords1])
skill_keywords1_dict = {ps.stem(tok):tok for tok in skill_keywords1}

degree_keywords1_set = set([ps.stem(tok) for tok in degree_dict.keys()])
degree_keywords1_dict = {ps.stem(tok):tok for tok in degree_dict.keys()}

# %%
tool_keywords1_dict
# Out:
# {'python': 'python',
#  'pytorch': 'pytorch',
#  'sql': 'sql',
#  'mxnet': 'mxnet',
#  'mlflow': 'mlflow',
#  'einstein': 'einstein',
#  'theano': 'theano',
#  'pyspark': 'pyspark',
#  'solr': 'solr',
#  'mahout': 'mahout',
#  'cassandra': 'cassandra',
#  'aw': 'aws',
#  'powerpoint': 'powerpoint',
#  'spark': 'spark',
#  'pig': 'pig',
#  'sa': 'sas',
#  'java': 'java',
#  'nosql': 'nosql',
#  'docker': 'docker',
#  'salesforc': 'salesforce',
#  'scala': 'scala',
#  'r': 'r',
#  'c': 'c',
#  'c++': 'c++',
#  'net': 'net',
#  'tableau': 'tableau',
#  'panda': 'pandas',
#  'scikitlearn': 'scikitlearn',
#  'sklearn': 'sklearn',
#  'matlab': 'matlab',
#  'kera': 'keras',
#  'tensorflow': 'tensorflow',
#  'clojur': 'clojure',
#  'caff': 'caffe',
#  'scipi': 'scipy',
#  'numpi': 'numpy',
#  'matplotlib': 'matplotlib',
#  'vba': 'vba',
#  'spss': 'spss',
#  'linux': 'linux',
#  'azur': 'azure',
#  'cloud': 'cloud',
#  'gcp': 'gcp',
#  'mongodb': 'mongodb',
#  'mysql': 'mysql',
#  'oracl': 'oracle',
#  'redshift': 'redshift',
#  'snowflak': 'snowflake',
#  'kafka': 'kafka',
#  'javascript': 'javascript',
#  'qlik': 'qlik',
#  'jupyt': 'jupyter',
#  'perl': 'perl',
#  'bigqueri': 'bigquery',
#  'unix': 'unix',
#  'react': 'react',
#  'scikit': 'scikit',
#  'powerbi': 'powerbi',
#  's3': 's3',
#  'ec2': 'ec2',
#  'lambda': 'lambda',
#  'ssr': 'ssrs',
#  'kubernet': 'kubernetes',
#  'hana': 'hana',
#  'spaci': 'spacy',
#  'tf': 'tf',
#  'django': 'django',
#  'sagemak': 'sagemaker',
#  'seaborn': 'seaborn',
#  'mllib': 'mllib',
#  'github': 'github',
#  'git': 'git',
#  'elasticsearch': 'elasticsearch',
#  'splunk': 'splunk',
#  'airflow': 'airflow',
#  'looker': 'looker',
#  'rapidmin': 'rapidminer',
#  'birt': 'birt',
#  'pentaho': 'pentaho',
#  'jqueri': 'jquery',
#  'nodej': 'nodejs',
#  'd3': 'd3',
#  'plotli': 'plotly',
#  'bokeh': 'bokeh',
#  'xgboost': 'xgboost',
#  'rstudio': 'rstudio',
#  'shini': 'shiny',
#  'dash': 'dash',
#  'h20': 'h20',
#  'h2o': 'h2o',
#  'hadoop': 'hadoop',
#  'mapreduc': 'mapreduce',
#  'hive': 'hive',
#  'cogno': 'cognos',
#  'angular': 'angular',
#  'nltk': 'nltk',
#  'flask': 'flask',
#  'node': 'node',
#  'firebas': 'firebase',
#  'bigtabl': 'bigtable',
#  'rust': 'rust',
#  'php': 'php',
#  'cntk': 'cntk',
#  'lightgbm': 'lightgbm',
#  'kubeflow': 'kubeflow',
#  'rpython': 'rpython',
#  'unixlinux': 'unixlinux',
#  'postgressql': 'postgressql',
#  'postgresql': 'postgresql',
#  'postgr': 'postgres',
#  'hbase': 'hbase',
#  'dask': 'dask',
#  'rubi': 'ruby',
#  'julia': 'julia',
#  'tensor': 'tensor',
#  'dplyr': 'dplyr',
#  'ggplot2': 'ggplot2',
#  'esquiss': 'esquisse',
#  'bioconductor': 'bioconductor',
#  'lubrid': 'lubridate',
#  'knitr': 'knitr',
#  'mlr': 'mlr',
#  'quanteda': 'quanteda',
#  'dt': 'dt',
#  'rcrawler': 'rcrawler',
#  'caret': 'caret',
#  'rmarkdown': 'rmarkdown',
#  'leaflet': 'leaflet',
#  'janitor': 'janitor',
#  'ggvi': 'ggvis',
#  'rchart': 'rcharts',
#  'rbokeh': 'rbokeh',
#  'broom': 'broom',
#  'stringr': 'stringr',
#  'magrittr': 'magrittr',
#  'slidifi': 'slidify',
#  'rvest': 'rvest',
#  'rmysql': 'rmysql',
#  'rsqlite': 'rsqlite',
#  'prophet': 'prophet',
#  'glmnet': 'glmnet',
#  'text2vec': 'text2vec',
#  'snowballc': 'snowballc',
#  'quantmod': 'quantmod',
#  'rstan': 'rstan',
#  'swirl': 'swirl',
#  'datascienc': 'datasciencer'}

# %%
df['job_description_word_set'].iloc[12]
# Out:
# {'1',
#  '2',
#  '3',
#  '30',
#  '30-45',
#  'abil',
#  'advanc',
#  'afraid',
#  'analysi',
#  'and/or',
#  'annual',
#  'artifici',
#  'asap',
#  'attract',
#  'batch',
#  'benefit',
#  'big',
#  'boston',
#  'brand',
#  'build',
#  'built',
#  'busi',
#  'c',
#  'calibr',
#  'chatbots…',
#  'claim',
#  'clean',
#  'client',
#  'code',
#  'comfort',
#  'compani',
#  'compens',
#  'convers',
#  'd',
#  'data',
#  'day-to-day',
#  'degre',
#  'demo',
#  'deploy',
#  'detail',
#  'detect',
#  'develop',
#  'differ',
#  'district',
#  'english',
#  'experi',
#  'expert',
#  'expertis',
#  'extract',
#  'face',
#  'familiar',
#  'fast-grow',
#  'feedback',
#  'financi',
#  'fit',
#  'fluent',
#  'fraud',
#  'french',
#  'full-tim',
#  'great',
#  'healthcar',
#  'hottest',
#  'hour',
#  'hr',
#  'imag',
#  'inform',
#  'innov',
#  'insid',
#  'insur',
#  'intellig',
#  'interview',
#  'junior',
#  'key',
#  'languag',
#  'last',
#  'lead',
#  'learn',
#  'leav',
#  'ma',
#  'machin',
#  'mathemat',
#  'member',
#  'min',
#  'model',
#  'more',
#  'nativ',
#  'need',
#  'new',
#  'next40',
#  'nlp',
#  'object-ori',
#  'offic',
#  'one',
#  'pari',
#  'payment',
#  'pension',
#  'perk',
#  'pipelin',
#  'plan',
#  'plu',
#  'process',
#  'product',
#  'profil',
#  'program',
#  'prospect',
#  'proud',
#  'qualiti',
#  'r',
#  'real-tim',
#  'recept',
#  'recogn',
#  'recruit',
#  'resum',
#  'role',
#  'sale',
#  'scienc',
#  'scientist',
#  'screen',
#  'set-up',
#  'shift',
#  'solut',
#  'speaker',
#  'special',
#  'standard',
#  'start',
#  'startup',
#  'statist',
#  'strong',
#  'synthesi',
#  'team',
#  'tech',
#  'technic',
#  'technolog',
#  'top',
#  'train',
#  'trend',
#  'trip',
#  'us',
#  'usa',
#  'user',
#  'way',
#  'will',
#  'wire',
#  'work',
#  '’'}

# %%
job_desc = df[msk].iloc[12]['job_description'].lower()
job_desc_set = df[msk].iloc[12]['job_description_word_set']
print(job_desc_set)
# Out:
# {'@', 'opportun', 'ancestri', 'unsolicit', 'race', 'person', 'access', '14', 'regard', 's', 'foundat', 'equal', 'employ', '/', 'background', 'nation', 'mentor', 'genet', 'keep', 'inform', 'vision', 'statist', 'yelp', 'python', 'color', 'plan', 'san', 'engin', 'ccpa', 'core', 'data', 'unbor', 'fair', 'degre', 'task', 'full', 'comfort', 'million', 'chanc', 'analys', 'collabor', 'arrest', 'research', 'user', 'problem', 'few', 'motiv', 'thousand', 'process', 'impact', '“', 'day', 'member', 'gender', 'servic', 'fun', 'pto', 'll', 'flexibl', 'sex', 'holiday', 'manag', 'model', 'agenc', 'number', 'strategi', 'authenticity.', 'econometr', '”', 'forecast', 'abstract', 'custom', 'insight', 'individu', 'unix', 'idea', 'busi', 'disabl', 'proud', 'convict', 'commut', 'accommod', 'respons', 'learn', 'intrigu', 'accommodations-recruit', 'production-grad', 'analysis/statist', 'r', 'way', 'plu', 'capabl', 'fee', 're', 'scienc', 'goal', 'curios', 'code', 'age', 'note', 'origin', 'due', 'trust', 'content', 'hundr', 'love', 'user-contribut', 'orient', 'save', 'condit', 'new', 'sens', 'variabl', '15', 'effort', 'develop', 'privaci', 'notic', '11', 'retir', 'other', 'softwar', 'sexual', 'perspect', 'interact', 'benefit', 'appli', 'qualifi', 'cultur', 'educ', 'modeling/machin', 'pursuant', 'ident', 'differ', 'product', 'sql/spark/python', 'cooper', 'dataset', 'detect', 'tenur', 'relationship', 'knowledg', 'commit', 'driven', 'auction', 'tie', 'applic', 'paid', 't', '415-969-8488', 'monthli', 'divers', 'end-to-end', 'predict', 'work', 'pipelin', 'piec', 'relat', 'disciplin', 'read', 'famili', 'account', 'characterist', 'expert', 'scientist', 'experi', 'veteran', 'beauti', 'complex', 'environ', 'exploratori', 'packag', 'advertis', 'system', 'such', 'parent', 'spend', 'human', 'medic', 'analysi', 'up', '401', 'recruit', 'list', 'well', 'yelp.com', 'infer', 'team', 'alia', 'safeti', 'persist', 'comput', 'math', 'express', 'francisco', 'solut', 'first', 'spam', 'week', 'ordin', 'record', '—', 'reason', 'k', 'pandas/statsmodels/sklearn', 'are', 'hard', 'job', 'uniqu', 'play', 'authent', 'valu', 'religion', 'subsidi', 'price', 'pre-tax', 'dental', 'larg', 'causal', 'promis', 'recommend', 'deep', 'demonstr', 'marit', 'employe', '’', 'support', 'resum', 'statu', 'quantit', 'end', 'area', 'bid'}
# <ipython-input-93-7b35cc1b716e>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# <ipython-input-93-7b35cc1b716e>:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
tool_list = []
skill_list = []
degree_list = []

msk = df['city'] != ''

num_postings = len(df[msk].index)
for i in range(num_postings):
    job_desc = df[msk].iloc[i]['job_description'].lower()
    job_desc_set = df[msk].iloc[i]['job_description_word_set']

    # check if the keywords are in the job description. Look for exact match by token.
    tool_words = tool_keywords1_set.intersection(job_desc_set)
    skill_words = skill_keywords1_set.intersection(job_desc_set)
    degree_words = degree_keywords1_set.intersection(job_desc_set)

    # check if longer keywords (more than one word) are in the job description. Match by substring.
    j = 0
    for tool_keyword2 in tool_keywords2:
        # tool keywords.
        if tool_keyword2 in job_desc:
            tool_list.append(tool_keyword2)
            j += 1

    k = 0
    for skill_keyword2 in skill_keywords2:
        # skill keywords.
        if skill_keyword2 in job_desc:
            skill_list.append(skill_keyword2)
            k += 1

    # search for the minimum education.
    min_education_level = 999
    for degree_word in degree_words:
        level = degree_dict[degree_keywords1_dict[degree_word]]
        min_education_level = min(min_education_level, level)

    for degree_keyword2 in degree_keywords2:
        # longer keywords. Match by substring.
        if degree_keyword2 in job_desc:
            level = degree_dict2[degree_keyword2]
            min_education_level = min(min_education_level, level)

    # label the job descriptions without any tool keywords.
    if len(tool_words) == 0 and j == 0:
        tool_list.append('nothing specified')

    # label the job descriptions without any skill keywords.
    if len(skill_words) == 0 and k == 0:
        skill_list.append('nothing specified')

    # If none of the keywords were found, but the word degree is present, then assume it's a bachelors level.
    if min_education_level > 500:
        if 'degree' in job_desc:
            min_education_level = 1

    tool_list += list(tool_words)
    skill_list += list(skill_words)
    degree_list.append(min_education_level)

# %%
tool_words
# Out:
# {'azur', 'c', 'hadoop', 'java', 'nosql', 'perl', 'python', 'spark', 'sql'}

# %%
tool_list
# Out:
# ['python',
#  'r',
#  'sql',
#  'kera',
#  'c++',
#  'r',
#  'tensor',
#  'amazon web services',
#  'tensorflow',
#  'tableau',
#  'powerbi',
#  'shini',
#  'r',
#  'qlik',
#  'spark',
#  'kera',
#  'aw',
#  'java',
#  'python',
#  'sql',
#  'hadoop',
#  'r',
#  'matlab',
#  's3',
#  'spark',
#  'aw',
#  'java',
#  'c++',
#  'python',
#  'git',
#  'net',
#  'powerpoint',
#  'r',
#  'sa',
#  'vba',
#  'amazon web services',
#  'tableau',
#  'seaborn',
#  'cloud',
#  'panda',
#  'r',
#  'matplotlib',
#  'spark',
#  'aw',
#  'python',
#  'sql',
#  'git',
#  'cloud',
#  'r',
#  'matlab',
#  'spark',
#  'scala',
#  'python',
#  'amazon web services',
#  'tensorflow',
#  'tableau',
#  'powerbi',
#  'shini',
#  'r',
#  'qlik',
#  'spark',
#  'kera',
#  'aw',
#  'java',
#  'python',
#  'sql',
#  'python',
#  'tensorflow',
#  'python',
#  'git',
#  'cloud',
#  'cloud',
#  'r',
#  'sa',
#  'c',
#  'aw',
#  'linux',
#  'c++',
#  'python',
#  'd3',
#  'c',
#  'r',
#  'python',
#  'r',
#  'hadoop',
#  'tensorflow',
#  'net',
#  'nosql',
#  'r',
#  'spark',
#  'scala',
#  'java',
#  'python',
#  'sql',
#  'cloud',
#  'r',
#  'matlab',
#  'spark',
#  'scala',
#  'python',
#  'python',
#  'aw',
#  'sql',
#  'cloud',
#  'r',
#  'matlab',
#  'spark',
#  'scala',
#  'python',
#  'python',
#  'unix',
#  'sql',
#  'java',
#  'python',
#  'sql',
#  'tensorflow',
#  'h2o',
#  'ec2',
#  'sagemak',
#  'shini',
#  'r',
#  'aw',
#  'scala',
#  'java',
#  'python',
#  'sql',
#  'git',
#  'github',
#  'r',
#  'matlab',
#  'bigqueri',
#  'git',
#  'sql',
#  'nothing specified',
#  'google cloud',
#  'cloud',
#  'panda',
#  'python',
#  'aw',
#  'numpi',
#  'panda',
#  'scipi',
#  'python',
#  'scikit',
#  'python',
#  'sql',
#  'java',
#  'pytorch',
#  'java',
#  'c++',
#  'python',
#  'tensorflow',
#  'python',
#  'git',
#  'github',
#  'numpi',
#  'panda',
#  'aw',
#  'python',
#  'cloud',
#  'python',
#  'unix',
#  'sql',
#  'java',
#  'r',
#  'matlab',
#  'c',
#  'java',
#  'c++',
#  'python',
#  'r',
#  'sa',
#  'matlab',
#  'python',
#  'sql',
#  'python',
#  'r',
#  'hadoop',
#  'numpi',
#  'pytorch',
#  'panda',
#  'r',
#  'kera',
#  'scala',
#  'java',
#  'c++',
#  'python',
#  'tensorflow',
#  'python',
#  'r',
#  'tableau',
#  'sa',
#  'unix',
#  'cloud',
#  'panda',
#  'javascript',
#  'matplotlib',
#  'aw',
#  'python',
#  'sql',
#  'r',
#  'spark',
#  'hive',
#  'python',
#  'sql',
#  'caret',
#  'github',
#  'panda',
#  'r',
#  'python',
#  'tensorflow',
#  'panda',
#  'r',
#  'mysql',
#  'python',
#  'sql',
#  'amazon web services',
#  'mllib',
#  'tensorflow',
#  'mxnet',
#  'ec2',
#  'cntk',
#  'caret',
#  'cloud',
#  'redshift',
#  'r',
#  's3',
#  'mlr',
#  'theano',
#  'caff',
#  'aw',
#  'kera',
#  'java',
#  'python',
#  'sql',
#  'cloud',
#  'python',
#  'r',
#  'sa',
#  'sql',
#  'python',
#  'r',
#  'sa',
#  'sql',
#  'splunk',
#  'react',
#  'hadoop',
#  'pig',
#  'kafka',
#  'cloud',
#  'solr',
#  'javascript',
#  'mysql',
#  'angular',
#  'postgr',
#  'c',
#  'java',
#  'hive',
#  'nodej',
#  'php',
#  'mahout',
#  'c++',
#  'tensorflow',
#  'solr',
#  'spaci',
#  'spark',
#  'kera',
#  'linux',
#  'elasticsearch',
#  'python',
#  'sql',
#  'hadoop',
#  'r',
#  'java',
#  'c',
#  'scala',
#  'php',
#  'c++',
#  'python',
#  'tensorflow',
#  'hadoop',
#  'redshift',
#  'r',
#  'spark',
#  'kera',
#  'hive',
#  'java',
#  'c++',
#  'python',
#  'sql',
#  'python',
#  'matlab',
#  'aw',
#  'sql',
#  'spark',
#  'linux',
#  'python',
#  'sql',
#  'git',
#  'pytorch',
#  'linux',
#  'python',
#  'git',
#  'tensorflow',
#  'sql',
#  'panda',
#  'aw',
#  'julia',
#  'python',
#  'sql',
#  'jupyt',
#  'tableau',
#  'cogno',
#  'r',
#  'qlik',
#  'azur',
#  'java',
#  'python',
#  'sql',
#  'c++',
#  'python',
#  'matlab',
#  'c',
#  'cloud',
#  'python',
#  'r',
#  'c',
#  'java',
#  'c++',
#  'python',
#  'sql',
#  'powerpoint',
#  'net',
#  'sa',
#  'cloud',
#  'python',
#  'linux',
#  'hadoop',
#  'tableau',
#  'powerbi',
#  'r',
#  'qlik',
#  'sa',
#  'python',
#  'sql',
#  'nothing specified',
#  'r',
#  'spark',
#  'scala',
#  'java',
#  'python',
#  'sql',
#  'amazon web services',
#  'mllib',
#  'tensorflow',
#  'mxnet',
#  'ec2',
#  'cntk',
#  'caret',
#  'cloud',
#  'redshift',
#  'r',
#  's3',
#  'mlr',
#  'theano',
#  'caff',
#  'aw',
#  'kera',
#  'java',
#  'python',
#  'sql',
#  'cloud',
#  'python',
#  'sql',
#  'git',
#  'mongodb',
#  'r',
#  'sa',
#  'julia',
#  'python',
#  'sql',
#  'python',
#  'google cloud',
#  'cloud',
#  'postgresql',
#  'r',
#  'aw',
#  'python',
#  'git',
#  'hadoop',
#  'pig',
#  'oracl',
#  'hive',
#  'sql',
#  'c',
#  'python',
#  'javascript',
#  'java',
#  'pytorch',
#  'caff',
#  'c++',
#  'python',
#  'tensorflow',
#  'tableau',
#  'nosql',
#  'hadoop',
#  'kafka',
#  'pytorch',
#  'postgresql',
#  'spss',
#  'docker',
#  'kubernet',
#  'spark',
#  'scala',
#  'java',
#  'c++',
#  'python',
#  'git',
#  'tensorflow',
#  'jupyt',
#  'nothing specified',
#  'panda',
#  'r',
#  'sa',
#  'hive',
#  'sql',
#  'github',
#  'numpi',
#  'hadoop',
#  'pig',
#  'r',
#  'postgr',
#  'hive',
#  'scipi',
#  'rubi',
#  'c++',
#  'python',
#  'sql',
#  'python',
#  'pyspark',
#  'hadoop',
#  'r',
#  'azur',
#  'spark',
#  'kera',
#  'aw',
#  'python',
#  'tensorflow',
#  'google cloud',
#  'r',
#  'vba',
#  'spark',
#  'python',
#  'tensorflow',
#  'github',
#  'r',
#  'kubernet',
#  'rubi',
#  'python',
#  'python',
#  'r',
#  'sa',
#  'sql',
#  'r',
#  'oracl',
#  'hadoop',
#  'cloud',
#  'r',
#  'rapidmin',
#  'spark',
#  'aw',
#  'hive',
#  'java',
#  'python',
#  'hadoop',
#  'mysql',
#  'spark',
#  'hive',
#  'python',
#  'nothing specified',
#  'nosql',
#  'hadoop',
#  'cloud',
#  'r',
#  'spark',
#  'python',
#  'sql',
#  'cloud',
#  'postgresql',
#  'gcp',
#  'aw',
#  'linux',
#  'rubi',
#  'java',
#  'c++',
#  'python',
#  'hadoop',
#  'javascript',
#  'spark',
#  'hive',
#  'java',
#  'python',
#  'sql',
#  'tableau',
#  'nosql',
#  'cloud',
#  'r',
#  'azur',
#  'aw',
#  'python',
#  'sql',
#  'ec2',
#  'tableau',
#  'redshift',
#  'aw',
#  'lambda',
#  'linux',
#  'python',
#  'sql',
#  'perl',
#  'rstudio',
#  'jupyt',
#  'pytorch',
#  'r',
#  'aw',
#  'java',
#  'python',
#  'tensorflow',
#  'sql',
#  'cloud',
#  'python',
#  'sql',
#  'powerpoint',
#  'r',
#  'sa',
#  'matlab',
#  'spss',
#  'c',
#  'c++',
#  'python',
#  'sql',
#  'pytorch',
#  'r',
#  'kera',
#  'python',
#  'tensorflow',
#  'python',
#  'r',
#  'sql',
#  'nosql',
#  'shini',
#  'r',
#  'python',
#  'sql',
#  'perl',
#  'python',
#  'r',
#  'tableau',
#  'airflow',
#  'docker',
#  'scala',
#  'java',
#  'python',
#  'sql',
#  'powerpoint',
#  'net',
#  'sa',
#  'python',
#  'r',
#  'tensorflow',
#  'matlab',
#  'python',
#  'git',
#  'python',
#  'r',
#  'matlab',
#  'react',
#  'numpi',
#  'kafka',
#  'sagemak',
#  'panda',
#  'javascript',
#  'scipi',
#  'cassandra',
#  'python',
#  'python',
#  'sql',
#  'looker',
#  'redshift',
#  'r',
#  'oracl',
#  'aw',
#  'scala',
#  'salesforc',
#  'python',
#  'sql',
#  'cloud',
#  'r',
#  'matlab',
#  'spark',
#  'scala',
#  'python',
#  'pytorch',
#  'spark',
#  'kera',
#  'python',
#  'tensorflow',
#  'sagemak',
#  'python',
#  'linux',
#  'aw',
#  'cloud',
#  'r',
#  'sa',
#  'aw',
#  'scala',
#  'java',
#  'python',
#  'nltk',
#  'r',
#  'xgboost',
#  'spaci',
#  'java',
#  'python',
#  'github',
#  'tableau',
#  'nosql',
#  'cloud',
#  'shini',
#  'r',
#  'ggplot2',
#  'linux',
#  'python',
#  'd3',
#  'sql',
#  'jupyt',
#  'python',
#  'r',
#  'github',
#  'r',
#  'python',
#  'sql',
#  'git',
#  'tensorflow',
#  'numpi',
#  'hadoop',
#  'pytorch',
#  'panda',
#  'mapreduc',
#  'dask',
#  'spark',
#  'elasticsearch',
#  'python',
#  'sql',
#  'python',
#  'r',
#  'rubi',
#  'matlab',
#  'panda',
#  'r',
#  'spark',
#  'python',
#  'sql',
#  'pytorch',
#  'kera',
#  'tensorflow',
#  'python',
#  'unix',
#  'sql',
#  'pytorch',
#  'caff',
#  'kera',
#  'julia',
#  'c++',
#  'python',
#  'tensorflow',
#  'ec2',
#  'mongodb',
#  'tableau',
#  'nosql',
#  'pig',
#  'shini',
#  'r',
#  's3',
#  'javascript',
#  'c',
#  'postgr',
#  'spark',
#  'hive',
#  'java',
#  'c++',
#  'python',
#  'sql',
#  'tensor',
#  'sagemak',
#  'azur',
#  'c',
#  'aw',
#  'c++',
#  'python',
#  'hadoop',
#  'r',
#  'sa',
#  'spark',
#  'cassandra',
#  'python',
#  'nosql',
#  'hadoop',
#  'powerbi',
#  'cloud',
#  'panda',
#  'gcp',
#  'qlik',
#  'java',
#  'sql',
#  'numpi',
#  'node',
#  'sa',
#  'spark',
#  'python',
#  'r',
#  'aw',
#  'jupyt',
#  'tableau',
#  'azur',
#  'nothing specified',
#  'pyspark',
#  'gcp',
#  'azur',
#  'spark',
#  'kera',
#  'aw',
#  'hive',
#  'python',
#  'tensorflow',
#  'python',
#  'sql',
#  'mxnet',
#  'tensor',
#  'java',
#  'c++',
#  'python',
#  'cloud',
#  'h2o',
#  'net',
#  'r',
#  'xgboost',
#  'c',
#  'spark',
#  'python',
#  'tensorflow',
#  'tableau',
#  'perl',
#  'github',
#  'unix',
#  'java',
#  'c++',
#  'python',
#  'sql',
#  'git',
#  'r',
#  'sa',
#  'matlab',
#  'spark',
#  'scala',
#  'java',
#  'python',
#  'git',
#  'tableau',
#  'r',
#  'c',
#  'python',
#  'sql',
#  'mllib',
#  'github',
#  'numpi',
#  'hadoop',
#  'cloud',
#  'gcp',
#  'r',
#  'azur',
#  'c',
#  'spark',
#  'aw',
#  'scala',
#  'scipi',
#  'java',
#  'python',
#  'pytorch',
#  'linux',
#  'python',
#  'git',
#  'tensorflow',
#  'sql',
#  'c',
#  'python',
#  'r',
#  'java',
#  'powerpoint',
#  'sql',
#  'python',
#  'linux',
#  'java',
#  'pytorch',
#  'caff',
#  'kera',
#  'c++',
#  'python',
#  'tensorflow',
#  'nosql',
#  'shini',
#  'gcp',
#  'kera',
#  'scala',
#  'linux',
#  'sql',
#  'h2o',
#  'pytorch',
#  'theano',
#  'python',
#  'd3',
#  'tensorflow',
#  'github',
#  'sagemak',
#  'r',
#  'aw',
#  'jupyt',
#  'tableau',
#  'ggplot2',
#  'tensorflow',
#  'hadoop',
#  'pytorch',
#  'panda',
#  'gcp',
#  'r',
#  'ggplot2',
#  'spark',
#  'aw',
#  'scala',
#  'rubi',
#  'java',
#  'python',
#  'sql',
#  'jupyt',
#  'powerpoint',
#  'python',
#  'r',
#  'sa',
#  'sql server',
#  'docker',
#  'oracl',
#  'javascript',
#  'angular',
#  'java',
#  'sql',
#  'r',
#  'sa',
#  'linux',
#  'shini',
#  'python',
#  'r',
#  'c',
#  'nothing specified',
#  'tableau',
#  'r',
#  'sa',
#  'python',
#  'sql',
#  'c++',
#  'c',
#  'sql',
#  'powerbi',
#  'cloud',
#  'postgresql',
#  'gcp',
#  'aw',
#  'linux',
#  'rubi',
#  'java',
#  'c++',
#  'python',
#  'python',
#  'spark',
#  'hadoop',
#  'sql',
#  'python',
#  'r',
#  'pytorch',
#  'tensorflow',
#  'nothing specified',
#  'hadoop',
#  'pig',
#  'r',
#  'sa',
#  'matlab',
#  'c',
#  'hive',
#  'java',
#  'c++',
#  'python',
#  'c++',
#  'python',
#  'github',
#  'hadoop',
#  'kafka',
#  'pytorch',
#  'java',
#  'spark',
#  'scala',
#  'julia',
#  'python',
#  'tensorflow',
#  'python',
#  'r',
#  'matlab',
#  'java',
#  'r',
#  'python',
#  'r',
#  'tableau',
#  'sql',
#  'r',
#  'docker',
#  'xgboost',
#  'spark',
#  'python',
#  'tensorflow',
#  'splunk',
#  'tableau',
#  'r',
#  'docker',
#  'matlab',
#  'python',
#  'hadoop',
#  'cloud',
#  'django',
#  'gcp',
#  'azur',
#  'kubernet',
#  'spark',
#  'aw',
#  'java',
#  'c++',
#  'python',
#  'sql server',
#  'mongodb',
#  'tableau',
#  'powerpoint',
#  'r',
#  'sa',
#  'spark',
#  'elasticsearch',
#  'python',
#  'sql',
#  'hadoop',
#  'r',
#  'sa',
#  'aw',
#  'linux',
#  'python',
#  'sql',
#  'c++',
#  'python',
#  'matlab',
#  'python',
#  'r',
#  'sa',
#  'matlab',
#  'python',
#  'spark',
#  'hadoop',
#  'sql',
#  'r',
#  'sa',
#  'matlab',
#  'spss',
#  'c',
#  'c++',
#  'python',
#  'sql',
#  'python',
#  'r',
#  'sql',
#  'tensorflow',
#  'hadoop',
#  'redshift',
#  'spark',
#  'hive',
#  'java',
#  'c++',
#  'sql',
#  'python',
#  'r',
#  'c',
#  'python',
#  'java',
#  'sql server',
#  'mongodb',
#  'nosql',
#  'postgresql',
#  ...]

# %% [markdown]
# #Visualizing the Results

# %% [markdown]
# ##Top Tools In-Demand

# %%
pd.DataFrame(data={'cnt': tool_list})
# Out:
#           cnt
# 0      python
# 1           r
# 2         sql
# 3        kera
# 4         c++
# ...       ...
# 13987       c
# 13988   spark
# 13989    java
# 13990  python
# 13991     sql
#
# [13992 rows x 1 columns]

# %%
# create the list of tools.
df_tool = pd.DataFrame(data={'cnt': tool_list})
df_tool = df_tool.replace(tool_keywords1_dict)

# group some of the categories together.
msk = df_tool['cnt'] == 'h20'
df_tool.loc[msk, 'cnt'] = 'h2o'

msk = df_tool['cnt'] == 'aws'
df_tool.loc[msk, 'cnt'] = 'amazon web services'

msk = df_tool['cnt'] == 'gcp'
df_tool.loc[msk, 'cnt'] = 'google cloud'

msk = df_tool['cnt'] == 'github'
df_tool.loc[msk, 'cnt'] = 'git'

msk = df_tool['cnt'] == 'postgressql'
df_tool.loc[msk, 'cnt'] = 'postgres'

msk = df_tool['cnt'] == 'tensor'
df_tool.loc[msk, 'cnt'] = 'tensorflow'

df_tool_top50 = df_tool['cnt'].value_counts().reset_index().rename(columns={'index': 'tool'}).iloc[:50]

# %%
df_tool_top50
# Out:
#                    tool   cnt
# 0                python  1651
# 1                   sql  1077
# 2                     r  1035
# 3                 spark   559
# 4                 cloud   530
# 5   amazon web services   527
# 6                  java   513
# 7            tensorflow   427
# 8                hadoop   401
# 9     nothing specified   378
# 10                  sas   354
# 11              tableau   339
# 12                  c++   299
# 13                scala   272
# 14         google cloud   244
# 15              pytorch   242
# 16                  git   213
# 17                    c   204
# 18                azure   204
# 19                 hive   192
# 20               pandas   169
# 21               matlab   168
# 22                keras   159
# 23                nosql   145
# 24           powerpoint   139
# 25                linux   139
# 26               docker   132
# 27           javascript   127
# 28                kafka   110
# 29                numpy   106
# 30             redshift   104
# 31                mysql    93
# 32           kubernetes    92
# 33               oracle    86
# 34                caffe    83
# 35                   s3    83
# 36              mongodb    80
# 37                 unix    79
# 38           sql server    78
# 39           salesforce    77
# 40                 spss    68
# 41              jupyter    68
# 42                 perl    64
# 43            cassandra    62
# 44                  pig    61
# 45                scipy    59
# 46              powerbi    58
# 47               looker    56
# 48              airflow    53
# 49                mxnet    52

# %%
# visualize the tools.
layout = dict(
    title='Tools For Data Scientists',
    yaxis=dict(
        title='% of job postings',
        tickformat=',.0%',
    )
)

fig = go.Figure(layout=layout)
fig.add_trace(go.Bar(
    x=df_tool_top50['tool'],
    y=df_tool_top50['cnt']/num_postings
))

# iplot(fig)
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f4b1fb0c-b99d-4ab2-953a-1a6c25f024fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4b1fb0c-b99d-4ab2-953a-1a6c25f024fd")) {                    Plotly.newPlot(                        "f4b1fb0c-b99d-4ab2-953a-1a6c25f024fd",                        [{"x":["python","sql","r","spark","cloud","amazon web services","java","tensorflow","hadoop","nothing specified","sas","tableau","c++","scala","google cloud","pytorch","git","c","azure","hive","pandas","matlab","keras","nosql","powerpoint","linux","docker","javascript","kafka","numpy","redshift","mysql","kubernetes","oracle","caffe","s3","mongodb","unix","sql server","salesforce","spss","jupyter","perl","cassandra","pig","scipy","powerbi","looker","airflow","mxnet"],"y":[0.6158149944050727,0.40171577769489,0.38604998135024243,0.2085042894442372,0.19768743006340916,0.19656844461022008,0.19134651249533757,0.15926892950391644,0.1495710555762775,0.1409921671018277,0.1320402834763148,0.12644535621036926,0.11152555016784782,0.10145468108914583,0.09101081685938082,0.09026482655725476,0.0794479671764267,0.07609101081685939,0.07609101081685939,0.07161506900410294,0.06303618052965311,0.06266318537859007,0.05930622901902275,0.054084296904140246,0.05184632599776203,0.05184632599776203,0.04923535994032078,0.047370384185005596,0.04102946661693398,0.03953748601268184,0.03879149571055576,0.034688549048862365,0.03431555389779933,0.03207758299142111,0.030958597538232,0.030958597538232,0.029839612085042894,0.02946661693397986,0.02909362178291682,0.028720626631853787,0.02536367027228646,0.02536367027228646,0.023871689668034317,0.023125699365908244,0.022752704214845206,0.022006713912719134,0.0216337187616561,0.020887728459530026,0.01976874300634092,0.01939574785527788],"type":"bar"}],                        {"title":{"text":"Tools For Data Scientists"},"yaxis":{"tickformat":",.0%","title":{"text":"% of job postings"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...

# %% [markdown]
# ##Top Skills In-Demand

# %%
# create the list of skills/knowledge.
df_skills = pd.DataFrame(data={'cnt': skill_list})
df_skills = df_skills.replace(skill_keywords1_dict)

# group some of the categories together.
msk = df_skills['cnt'] == 'nlp'
df_skills.loc[msk, 'cnt'] = 'natural language processing'

msk = df_skills['cnt'] == 'convolutional'
df_skills.loc[msk, 'cnt'] = 'convolutional neural network'

msk = df_skills['cnt'] == 'cnn'
df_skills.loc[msk, 'cnt'] = 'convolutional neural network'

msk = df_skills['cnt'] == 'recurrent'
df_skills.loc[msk, 'cnt'] = 'recurrent neural network'

msk = df_skills['cnt'] == 'rnn'
df_skills.loc[msk, 'cnt'] = 'recurrent neural network'

msk = df_skills['cnt'] == 'knn'
df_skills.loc[msk, 'cnt'] = 'nearest neighbors'

msk = df_skills['cnt'] == 'svm'
df_skills.loc[msk, 'cnt'] = 'support vector machine'

msk = df_skills['cnt'] == 'machine vision'
df_skills.loc[msk, 'cnt'] = 'computer vision'

msk = df_skills['cnt'] == 'ab testing'
df_skills.loc[msk, 'cnt'] = 'a/b testing'

df_skills_top50 = df_skills['cnt'].value_counts().reset_index().rename(columns={'index': 'skill'}).iloc[:50]

# %%
# visualize the skills.
layout = dict(
    title='Skills For Data Scientists',
    yaxis=dict(
        title='% of job postings',
        tickformat=',.0%',
    )
)

fig = go.Figure(layout=layout)
fig.add_trace(go.Bar(
    x=df_skills_top50['skill'],
    y=df_skills_top50['cnt']/num_postings
))

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2f42c5f0-c122-4ae2-8cd4-8d54a5e2af6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f42c5f0-c122-4ae2-8cd4-8d54a5e2af6b")) {                    Plotly.newPlot(                        "2f42c5f0-c122-4ae2-8cd4-8d54a5e2af6b",                        [{"x":["machine learning","statistics","research","prediction","visualization","recommendations","optimizing","deep learning","natural language processing","regression","data mining","classification","supervised","neural network","dashboard","forecasting","segmentation","computer vision","cleaning","etl","cluster","logistic","time series","unsupervised","graph","decision tree","kpi","reinforcement","hypothesis","probability","experimental design","econometrics","biostatistics","exploratory","bayesian","anomaly","bayes","causality","support vector machine","random forest","bioinformatics","convolutional neural network","a/b testing","power bi","nothing specified","tuning","chatbot","recurrent neural network","cleansing","boosting"],"y":[0.6437896307348004,0.5897053338306601,0.5031704587840358,0.2812383439015293,0.2558746736292428,0.23013800820589334,0.22752704214845207,0.20290936217829167,0.19843342036553524,0.12420738530399104,0.12420738530399104,0.09735173442745244,0.09212980231256994,0.09101081685938082,0.08728086534875047,0.08280492353599403,0.07198806415516598,0.0701230883998508,0.06937709809772473,0.06751212234240955,0.05930622901902275,0.05147333084669899,0.04923535994032078,0.044386422976501305,0.04177545691906005,0.041402461767997015,0.03879149571055576,0.03804550540842969,0.037672510257366655,0.03729951510630362,0.03580753450205147,0.034688549048862365,0.034688549048862365,0.034688549048862365,0.033942558746736295,0.03319656844461022,0.03245057814248415,0.03207758299142111,0.02909362178291682,0.028720626631853787,0.027974636329727715,0.026855650876538604,0.026855650876538604,0.023125699365908244,0.022006713912719134,0.020887728459530026,0.01641178664677359,0.016038791495710556,0.015665796344647518,0.015292801193584483],"type":"bar"}],                        {"title":{"text":"Skills For Data Scientists"},"yaxis":{"tickformat":",.0%","title":{"text":"% of job postings"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#f ...

# %% [markdown]
# ##Minimum Education Required

# %%
# create the list of degree.
df_degrees = pd.DataFrame(data={'cnt': degree_list})
df_degrees['degree_type'] = ''


msk = df_degrees['cnt'] == 1
df_degrees.loc[msk, 'degree_type'] = 'bachelors'

msk = df_degrees['cnt'] == 2
df_degrees.loc[msk, 'degree_type'] = 'masters'

msk = df_degrees['cnt'] == 3
df_degrees.loc[msk, 'degree_type'] = 'phd'

msk = df_degrees['cnt'] == 4
df_degrees.loc[msk, 'degree_type'] = 'postdoc'

msk = df_degrees['cnt'] == 2.5
df_degrees.loc[msk, 'degree_type'] = 'mba'

msk = df_degrees['cnt'] > 500
df_degrees.loc[msk, 'degree_type'] = 'not specified'


df_degree_cnt = df_degrees['degree_type'].value_counts().reset_index().rename(columns={'index': 'degree'}).iloc[:50]

# %%
# visualize the degrees.
layout = dict(
    title='Minimum Education For Data Scientists',
    yaxis=dict(
        title='% of job postings',
        tickformat=',.0%',
    )
)

fig = go.Figure(layout=layout)
fig.add_trace(go.Bar(
    x=df_degree_cnt['degree'],
    y=df_degree_cnt['degree_type']/num_postings
))

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="318383f0-c172-4d88-9c18-f3bbed690c3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("318383f0-c172-4d88-9c18-f3bbed690c3e")) {                    Plotly.newPlot(                        "318383f0-c172-4d88-9c18-f3bbed690c3e",                        [{"x":["bachelors","masters","not specified","phd","postdoc","mba"],"y":[0.49198060425214474,0.27377844088026854,0.1462140992167102,0.08728086534875047,0.0003729951510630362,0.0003729951510630362],"type":"bar"}],                        {"title":{"text":"Minimum Education For Data Scientists"},"yaxis":{"tickformat":",.0%","title":{"text":"% of job postings"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{ ...
